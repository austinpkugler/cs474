# %%
import tensorflow.keras as keras
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.initializers import GlorotNormal
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from sklearn.model_selection import KFold

import time
from statistics import mean


def load_fashion_mnist():
    (X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
    X_train = X_train.reshape((X_train.shape[0], 28, 28, 1)).astype('float32') / 255.0
    X_test = X_test.reshape((X_test.shape[0], 28, 28, 1)).astype('float32') / 255.0
    y_train_onehot = keras.utils.to_categorical(y_train)
    y_test_onehot = keras.utils.to_categorical(y_test)
    return X_train, y_train_onehot, X_test, y_test_onehot


class Model:

    def __init__(self):
        self.model = Sequential()

    def build(self):
        self.model.add(Conv2D(32, 3, activation='relu', kernel_initializer=GlorotNormal(), input_shape=(28, 28, 1)))
        self.model.add(MaxPooling2D())
        self.model.add(Dropout(0.25))
        self.model.add(Flatten())
        self.model.add(Dense(64, activation='relu'))
        self.model.add(Dense(64, activation='relu'))
        self.model.add(Dense(64, activation='relu'))
        self.model.add(Dense(10, activation='softmax'))
        self.model.compile(optimizer=SGD(momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

    def validate(self, X, Y, K):
        train_accs = []
        test_accs = []
        kfold = KFold(K, shuffle=True, random_state=1)
        k_count = 1
        for i_train, i_test in kfold.split(X):
            X_train, y_train, X_test, y_test = X[i_train], Y[i_train], X[i_test], Y[i_test]
            self.model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

            _, train_acc = self.model.evaluate(X_train, y_train)
            train_accs.append(train_acc)

            _, test_acc = self.model.evaluate(X_test, y_test)
            test_accs.append(test_acc)

            k_count += 1

        return train_accs, test_accs


start = time.time()
X_train, y_train, X_test, y_test = load_fashion_mnist()
model = Model()
model.build()
train_accs, test_accs = model.validate(X_train, y_train, 5)
print(f'Train Accuracy: {round(mean(train_accs) * 100, 2)}%')
print(f'Test Accuracy: {round(mean(test_accs) * 100, 2)}%')
runtime = round(int(time.time() - start) / 60, 2)
print(f'--- {runtime}m ---')
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.6003 - accuracy: 0.7773 - val_loss: 0.3970 - val_accuracy: 0.8543
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3647 - accuracy: 0.8668 - val_loss: 0.3543 - val_accuracy: 0.8723
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3148 - accuracy: 0.8835 - val_loss: 0.3132 - val_accuracy: 0.8850
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2865 - accuracy: 0.8929 - val_loss: 0.3103 - val_accuracy: 0.8831
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2635 - accuracy: 0.9015 - val_loss: 0.2743 - val_accuracy: 0.9005
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2453 - accuracy: 0.9086 - val_loss: 0.2744 - val_accuracy: 0.8980
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2303 - accuracy: 0.9129 - val_loss: 0.2612 - val_accuracy: 0.9053
# Epoch 8/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2151 - accuracy: 0.9197 - val_loss: 0.2744 - val_accuracy: 0.9019
# Epoch 9/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2091 - accuracy: 0.9209 - val_loss: 0.2729 - val_accuracy: 0.9046
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1968 - accuracy: 0.9268 - val_loss: 0.2520 - val_accuracy: 0.9104
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1450 - accuracy: 0.9457
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2520 - accuracy: 0.9104
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2125 - accuracy: 0.9210 - val_loss: 0.1658 - val_accuracy: 0.9377
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1963 - accuracy: 0.9267 - val_loss: 0.1753 - val_accuracy: 0.9356
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1852 - accuracy: 0.9314 - val_loss: 0.1734 - val_accuracy: 0.9343
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1759 - accuracy: 0.9335 - val_loss: 0.1749 - val_accuracy: 0.9358
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1676 - accuracy: 0.9361 - val_loss: 0.1810 - val_accuracy: 0.9341
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1601 - accuracy: 0.9400 - val_loss: 0.1880 - val_accuracy: 0.9313
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1560 - accuracy: 0.9406 - val_loss: 0.2000 - val_accuracy: 0.9272
# Epoch 8/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1464 - accuracy: 0.9448 - val_loss: 0.1992 - val_accuracy: 0.9265
# Epoch 9/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1449 - accuracy: 0.9455 - val_loss: 0.2014 - val_accuracy: 0.9252
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1394 - accuracy: 0.9472 - val_loss: 0.2233 - val_accuracy: 0.9216
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1116 - accuracy: 0.9561
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2233 - accuracy: 0.9216
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1599 - accuracy: 0.9409 - val_loss: 0.1120 - val_accuracy: 0.9579
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1489 - accuracy: 0.9431 - val_loss: 0.1138 - val_accuracy: 0.9557
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1412 - accuracy: 0.9457 - val_loss: 0.1267 - val_accuracy: 0.9497
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1334 - accuracy: 0.9495 - val_loss: 0.1164 - val_accuracy: 0.9553
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1275 - accuracy: 0.9515 - val_loss: 0.1276 - val_accuracy: 0.9536
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1189 - accuracy: 0.9549 - val_loss: 0.1253 - val_accuracy: 0.9515
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1185 - accuracy: 0.9552 - val_loss: 0.1365 - val_accuracy: 0.9487
# Epoch 8/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1151 - accuracy: 0.9563 - val_loss: 0.1335 - val_accuracy: 0.9498
# Epoch 9/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1122 - accuracy: 0.9573 - val_loss: 0.1512 - val_accuracy: 0.9465
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1100 - accuracy: 0.9583 - val_loss: 0.1435 - val_accuracy: 0.9475
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0690 - accuracy: 0.9753
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1435 - accuracy: 0.9475
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1284 - accuracy: 0.9522 - val_loss: 0.0758 - val_accuracy: 0.9741
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1185 - accuracy: 0.9552 - val_loss: 0.0936 - val_accuracy: 0.9627
# Epoch 3/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1112 - accuracy: 0.9584 - val_loss: 0.0970 - val_accuracy: 0.9622
# Epoch 4/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1056 - accuracy: 0.9606 - val_loss: 0.0937 - val_accuracy: 0.9628
# Epoch 5/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1019 - accuracy: 0.9621 - val_loss: 0.0853 - val_accuracy: 0.9673
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0989 - accuracy: 0.9632 - val_loss: 0.1099 - val_accuracy: 0.9576
# Epoch 7/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0941 - accuracy: 0.9645 - val_loss: 0.1023 - val_accuracy: 0.9622
# Epoch 8/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0936 - accuracy: 0.9642 - val_loss: 0.1028 - val_accuracy: 0.9604
# Epoch 9/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0898 - accuracy: 0.9656 - val_loss: 0.1096 - val_accuracy: 0.9578
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0887 - accuracy: 0.9663 - val_loss: 0.1047 - val_accuracy: 0.9614
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0459 - accuracy: 0.9847
# 375/375 [==============================] - 1s 1ms/step - loss: 0.1047 - accuracy: 0.9614
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1076 - accuracy: 0.9595 - val_loss: 0.0602 - val_accuracy: 0.9794
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0995 - accuracy: 0.9622 - val_loss: 0.0678 - val_accuracy: 0.9739
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0919 - accuracy: 0.9660 - val_loss: 0.0735 - val_accuracy: 0.9727
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0905 - accuracy: 0.9656 - val_loss: 0.0605 - val_accuracy: 0.9777
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0837 - accuracy: 0.9681 - val_loss: 0.0634 - val_accuracy: 0.9757
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0832 - accuracy: 0.9690 - val_loss: 0.0690 - val_accuracy: 0.9741
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0776 - accuracy: 0.9709 - val_loss: 0.0850 - val_accuracy: 0.9677
# Epoch 8/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0827 - accuracy: 0.9690 - val_loss: 0.0804 - val_accuracy: 0.9704
# Epoch 9/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0767 - accuracy: 0.9711 - val_loss: 0.0826 - val_accuracy: 0.9685
# Epoch 10/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0768 - accuracy: 0.9712 - val_loss: 0.0744 - val_accuracy: 0.9736
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0322 - accuracy: 0.9894
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0744 - accuracy: 0.9736
# Train Accuracy: 97.02%
# Test Accuracy: 94.29%
# --- 5.6m ---
